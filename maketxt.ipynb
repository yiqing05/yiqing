# %%
import os
import random
 
trainval_percent = 0.1
train_percent = 0.9
xmlfilepath = 'data/Annotations'
txtsavepath = 'data/ImageSets'
total_xml = os.listdir(xmlfilepath)
 
num = len(total_xml)
list = range(num)
tv = int(num * trainval_percent)
tr = int(tv * train_percent)
trainval = random.sample(list, tv)
train = random.sample(trainval, tr)
 
ftrainval = open('data/ImageSets/trainval.txt', 'w')
ftest = open('data/ImageSets/test.txt', 'w')
ftrain = open('data/ImageSets/train.txt', 'w')
fval = open('data/ImageSets/val.txt', 'w')

a=0
for i in list:
    a+=1
    name = total_xml[i][:-4] + '\n'
    if i in trainval:
        ftrainval.write(name)
        if i in train:
            ftest.write(name)
        else:
            fval.write(name)
    else:
        ftrain.write(name)
        
print(a)
ftrainval.close()
ftrain.close()
fval.close()
ftest.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-be8ec134aa5c> in <module>()
#       6 xmlfilepath = 'data/Annotations'
#       7 txtsavepath = 'data/ImageSets'
# ----> 8 total_xml = os.listdir(xmlfilepath)
#       9
#      10 num = len(total_xml)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Annotations'
